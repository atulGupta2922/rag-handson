# %% [markdown]
# ## Loading Data
# ### Ingestion pipline:
# `Load the data` -> `Transform the data` -> `Store and Index the data`

# %% [markdown]
# * Load the data

# %%
from llama_index.core import SimpleDirectoryReader

document = SimpleDirectoryReader(input_files=['data/Hackers-Painters-BigIdeasFromTheComputerAgebyPaulGraham.pdf']).load_data()

# %%
len(document)
# Out:
# 274

# %%
document[16].__dict__
# Out:
# {'id_': '051963d5-8d80-4fa0-a5bb-fb24a91bc15e',
#  'embedding': None,
#  'metadata': {'page_label': '3',
#   'file_name': 'Hackers-Painters-BigIdeasFromTheComputerAgebyPaulGraham.pdf',
#   'file_path': 'data/Hackers-Painters-BigIdeasFromTheComputerAgebyPaulGraham.pdf',
#   'file_type': 'application/pdf',
#   'file_size': 1742887,
#   'creation_date': '2025-06-30',
#   'last_modified_date': '2025-06-30'},
#  'excluded_embed_metadata_keys': ['file_name',
#   'file_type',
#   'file_size',
#   'creation_date',
#   'last_modified_date',
#   'last_accessed_date'],
#  'excluded_llm_metadata_keys': ['file_name',
#   'file_type',
#   'file_size',
#   'creation_date',
#   'last_modified_date',
#   'last_accessed_date'],
#  'relationships': {},
#  'metadata_template': '{key}: {value}',
#  'metadata_separator': '\n',
#  'text_resource': MediaResource(embeddings=None, data=None, text='why nerds are unpopular\nit would be a step up. Even for someone in the eightieth per-\ncentile (assuming, as everyone seemed to then, that intelligence is\na scalar), who wouldn’t drop thirty points in exchange for being\nl o v e da n da d m i r e db ye v e r y o n e ?\nAnd that, I think, is the root of the problem. Nerds serve two\nmasters. They want to be popular, certainly, but they want even\nmore to be smart. And popularity is not something you can do\nin your spare time, not in the ﬁercely competitive environment of\nan American secondary school.\nAlberti, arguably the archetype of the Renaissance Man, writes that\n“no art, however minor, demands less than total dedication if you\nwant to excel in it.”\n1 I wonder if anyone in the world works harder\nat anything than American school kids work at popularity. Navy\nSeals and neurosurgery residents seem slackers by comparison.\nThey occasionally take vacations; some even have hobbies. An\nAmerican teenager may work at being popular every waking hour,\n365 days a year.\nI don’t mean to suggest they do this consciously. Some of\nthem truly are little Machiavellis, but what I really mean here is\nthat teenagers are always on duty as conformists.\nFor example, teenage kids pay a great deal of attention to\nclothes. They don’t consciously dress to be popular. They dress\nto look good. But to who? To the other kids. Other kids’ opin-\nions become their deﬁnition of right, not just for clothes, but for\nalmost everything they do, right down to the way they walk. And\nso every effort they make to do things “right” is also, consciously\nor not, an effort to be more popular.\nNerds don’t realize this. They don’t realize that it takes work\nto be popular. In general, people outside some very demanding\nﬁeld don’t realize the extent to which success depends on constant\n(though often unconscious) effort. For example, most people seem\nto consider the ability to draw as some kind of innate quality, like\nbeing tall. In fact, most people who “can draw” like drawing, and\nhave spent many hours doing it; that’s why they’re good at it.\n3\n', path=None, url=None, mimetype=None),
#  'image_resource': None,
#  'audio_resource': None,
#  'video_resource': None,
#  'text_template': '{metadata_str}\n\n{content}'}

# %%
from llama_index.core import Document

manual_doc = Document(text="This a random text for manual document in llama-index.")
# metadata can also be added to Document
# manual_doc = Document(text="This a random text for manual document in llama-index.", metadata = {'filename': "text.txt"})

# %%
manual_doc.__dict__
# Out:
# {'id_': '112baa88-76d2-41d0-90f0-e4bc91059686',
#  'embedding': None,
#  'metadata': {},
#  'excluded_embed_metadata_keys': [],
#  'excluded_llm_metadata_keys': [],
#  'relationships': {},
#  'metadata_template': '{key}: {value}',
#  'metadata_separator': '\n',
#  'text_resource': MediaResource(embeddings=None, data=None, text='This a random text for manual document in llama-index.', path=None, url=None, mimetype=None),
#  'image_resource': None,
#  'audio_resource': None,
#  'video_resource': None,
#  'text_template': '{metadata_str}\n\n{content}'}

# %% [markdown]
# * Transform Data

# %%
from llama_index.core.node_parser import SentenceSplitter

parser = SentenceSplitter(
    chunk_size=128, # in tokens
    chunk_overlap=16, #in tokens
    paragraph_separator="\n\n"
)

nodes = parser.get_nodes_from_documents(documents=document, show_progress=True)
# Out:
# Parsing nodes: 100%|██████████| 274/274 [00:00<00:00, 738.27it/s]

# %%
len(nodes)
# Out:
# 1692

# %%
nodes[76].__dict__
# Out:
# {'id_': 'f04fcf19-7b53-47cd-9435-910d0088cbab',
#  'embedding': None,
#  'metadata': {'page_label': '8',
#   'file_name': 'Hackers-Painters-BigIdeasFromTheComputerAgebyPaulGraham.pdf',
#   'file_path': 'data/Hackers-Painters-BigIdeasFromTheComputerAgebyPaulGraham.pdf',
#   'file_type': 'application/pdf',
#   'file_size': 1742887,
#   'creation_date': '2025-06-30',
#   'last_modified_date': '2025-06-30'},
#  'excluded_embed_metadata_keys': ['file_name',
#   'file_type',
#   'file_size',
#   'creation_date',
#   'last_modified_date',
#   'last_accessed_date'],
#  'excluded_llm_metadata_keys': ['file_name',
#   'file_type',
#   'file_size',
#   'creation_date',
#   'last_modified_date',
#   'last_accessed_date'],
#  'relationships': {<NodeRelationship.SOURCE: '1'>: RelatedNodeInfo(node_id='be1794e6-7434-426d-a312-d2635fcd4413', node_type=<ObjectType.DOCUMENT: '4'>, metadata={'page_label': '8', 'file_name': 'Hackers-Painters-BigIdeasFromTheComputerAgebyPaulGraham.pdf', 'file_path': 'data/Hackers-Painters-BigIdeasFromTheComputerAgebyPaulGraham.pdf', 'file_type': 'application/pdf', 'file_size': 1742887, 'creation_date': '2025-06-30', 'last_modified_date': '2025-06-30'}, hash='1e26bfe313983a3e6f30e6ec825c64092600e217b5f0769f21ffb75d1e11d01c'),
#   <NodeRelationship.NEXT: '3'>: RelatedNodeInfo(node_id='1b473c29-e587-44c2-ba3e-99dacc6c5bb2', node_type=<ObjectType.TEXT: '1'>, metadata={}, hash='34a335db4f31c8693343802bdb33c4d70c3eda578b014fc14c7a2c72bac07865')},
#  'metadata_template': '{key}: {value}',
#  'metadata_separator': '\n',
#  'text': 'hackers & painters\nin the abstract that people get tortured in poorer countries. But,\nlike us, they don’t like to dwell on this depressing fact, and they\ndon’t see evidence of speciﬁc abuses unless they go looking for it.\nPublic school teachers are in much the same position as prison\nwardens. Wardens’ main concern is to keep the prisoners on the\npremises.',
#  'mimetype': 'text/plain',
#  'start_char_idx': 0,
#  'end_char_idx': 357,
#  'metadata_seperator': '\n',
#  'text_template': '{metadata_str}\n\n{content}'}

# %%
import os

from getpass import getpass
import nest_asyncio

from dotenv import load_dotenv

nest_asyncio.apply()

load_dotenv()


CO_API_KEY = os.environ['CO_API_KEY'] or getpass("Enter your Cohere API key: ")
OPENAI_API_KEY = os.environ['OPENAI_API_KEY'] or getpass("Enter your OpenAI API key: ")
QDRANT_URL = os.environ['QDRANT_URL'] or getpass("Enter your Qdrant URL:")
QDRANT_API_KEY = os.environ['QDRANT_API_KEY'] or  getpass("Enter your Qdrant API Key:")
AZURE_AI_SEARCH_ENDPOINT= os.environ['AZURE_AI_SEARCH_ENDPOINT']
AZURE_AI_SEARCH_API_KEY= os.environ['AZURE_AI_SEARCH_API_KEY']
AZURE_OPENAI_ENDPOINT= os.environ['AZURE_OPENAI_ENDPOINT']
AZURE_API_KEY= os.environ['AZURE_API_KEY']

# %% [markdown]
# * Index Data

# %%
CO_API_KEY = os.environ['CO_API_KEY'] or getpass("Enter your Cohere API key: ")

# %%
from llama_index.embeddings.cohere import CohereEmbedding

embed_v3 = CohereEmbedding(model_name="embed-english-v3.0", api_key=CO_API_KEY)

embed_v3_light = CohereEmbedding(model_name="embed-english-light-v3.0", api_key=CO_API_KEY)

embed_v2 = CohereEmbedding(model_name="embed-english-v2.0", api_key=CO_API_KEY)

# %%
string = "A"

string_0 = "This is a complete sentence."
string_2 = """In the pursuit of a life well-lived, one must recognize the transient nature of the 
material world and the enduring value of virtue. The Sikh Gurus taught us that the Divine Light 
resides within all, and thus, we are united in our essence beyond the superficial distinctions of 
caste, creed, or status. Similarly, the Stoics emphasized the cultivation of inner virtues such as courage, 
temperance, and wisdom, understanding that true freedom lies in mastery over one's own perceptions and actions. 
As we navigate the vicissitudes of life, let us remember that our choices are our own"""

string_3 = """In the pursuit of a life well-lived, one must recognize the transient nature of the 
material world and the enduring value of virtue. The Sikh Gurus taught us that the Divine Light 
resides within all, and thus, we are united in our essence beyond the superficial distinctions of 
caste, creed, or status. Similarly, the Stoics emphasized the cultivation of inner virtues such as courage, 
temperance, and wisdom, understanding that true freedom lies in mastery over one's own perceptions and actions. 
As we navigate the vicissitudes of life, let us remember that our choices are our own, and in choosing virtue, 
we align ourselves with the cosmic order and the teachings of the Gurus. It is through selfless service, 
compassion, and the relentless pursuit of truth that we may attain a state of inner peace and contribute 
to the harmony of the world, embodying the principles of both Sikhism and Stoicism in our daily lives
"""

# %%
example_embedding = embed_v3.get_text_embedding(string)

# %%
len(example_embedding)
# Out:
# 1024

# %%
embedding2 = embed_v3_light.get_text_embedding(string)

# %%
len(embedding2)
# Out:
# 384

# %%
embedding3 = embed_v2.get_text_embedding(string)

# %%
len(embedding3)
# Out:
# 4096

# %% [markdown]
# [comparing similarity]

# %%
embed_v3.similarity(
    embed_v3.get_text_embedding(string_3),
    embed_v3.get_text_embedding(string_2),
    mode="cosine"
)
# Out:
# np.float64(0.9612125127558748)

# %% [markdown]
# ## Creating index from scratch

# %%
import requests

def load_text_from_url(url):
    response = requests.get(url)
    response.raise_for_status
    return response.text

url = "https://www.gutenberg.org/cache/epub/10763/pg10763.txt"
text_content = load_text_from_url(url)

# %%
from llama_index.core import Document, VectorStoreIndex

document = Document(text=text_content[50000:60000])

# %%
index = VectorStoreIndex.from_documents(
    documents=[document],
    embed_model=embed_v3,
    show_progress=True
)
# Out:
# Parsing nodes:   0%|          | 0/1 [00:00<?, ?it/s]
# Parsing nodes: 100%|██████████| 1/1 [00:00<00:00, 21.43it/s]
# Generating embeddings: 100%|██████████| 3/3 [00:09<00:00,  3.04s/it]

# %%
index.__dict__
# Out:
# {'_use_async': False,
#  '_store_nodes_override': False,
#  '_embed_model': CohereEmbedding(model_name='embed-english-v3.0', embed_batch_size=10, callback_manager=<llama_index.core.callbacks.base.CallbackManager object at 0x13ec0ef10>, num_workers=None, embeddings_cache=None, api_key='tLD3G1ZJFKFa0VSNSSBfBsWtn22ICpQsvCHduoYm', base_url=None, truncate='END', input_type=None, embedding_type='float'),
#  '_insert_batch_size': 2048,
#  '_storage_context': StorageContext(docstore=<llama_index.core.storage.docstore.simple_docstore.SimpleDocumentStore object at 0x14aaf2f90>, index_store=<llama_index.core.storage.index_store.simple_index_store.SimpleIndexStore object at 0x14aaf3380>, vector_stores={'default': SimpleVectorStore(stores_text=False, is_embedding_query=True, data=SimpleVectorStoreData(embedding_dict={'fb1624a5-35ea-49d7-a575-ad6b79905f3d': [0.061157227, -0.003583908, 0.07043457, 0.036010742, -0.010551453, -0.010726929, 0.05618286, -0.06951904, -0.021194458, 0.007637024, -0.050750732, 0.022216797, -0.055145264, -0.0037384033, -0.0012865067, -0.07910156, -0.02494812, 0.037322998, -0.014656067, -0.035858154, 0.0043258667, -0.047912598, -0.023635864, -0.019348145, 0.06695557, -0.017990112, -0.0025863647, -0.00907135, 0.03366089, 0.003686905, 0.035614014, -0.025802612, 0.009468079, 0.03302002, -0.010932922, 0.019592285, -0.009666443, 0.009223938, 0.016143799, 0.0028018951, 0.014625549, 0.009918213, -0.05706787, 0.015182495, -0.088012695, -0.022781372, -0.031463623, 0.017837524, 0.036621094, 0.021865845, 0.046447754, 0.016036987, 0.035736084, 0.044433594, -0.024215698, 0.029373169, -0.0009965897, -0.021865845, 0.017608643, -0.0025787354, 0.008735657, 0.010498047, 0.013282776, 0.020431519, 0.0073890686, -0.0017194748, 0.026809692, -0.008506775, 0.06329346, 0.028198242, -0.004589081, 0.031173706, 0.006958008, -0
, -0.026290894, 0.01499176, -0.01826477, -0.028701782, -0.014045715, 0.012329102, -0.031463623, 0.072021484, -0.052093506, -0.017349243, -0.012580872, -0.003982544, -0.0052337646, 0.009849548, -0.026443481, 0.058380127, -0.05090332, -0.04611206, 0.002588272, 0.015525818, 0.003206253, 0.030776978, 0.04168701, -0.01234436, -0.0015039444, -0.018737793, 0.029724121, 0.055114746, -0.017456055, -0.047943115, 0.034851074, -0.054351807, 0.011222839, -0.0496521, 0.0052719116, -0.007419586, 0.011314392, 0.0018463135, 0.03466797, 0.038848877, 0.024810791, 0.022094727, -0.016723633, 0.02130127, -0.061187744, 0.009338379, 0.02456665, 0.025283813, -0.029968262, 0.013450623, -0.013160706, -0.058013916, 0.026306152, 0.01852417, 0.019317627, -0.078552246, 0.023788452, 0.0680542, -0.005470276, 0.033111572, 0.00579834, -0.06555176, -0.01461792, 0.0058021545, -0.018737793, -0.022827148, 0.004032135, 0.016311646, 0.0021438599, -0.013458252, 0.01158905, -0.025558472 ...
#  '_graph_store': <llama_index.core.graph_stores.simple.SimpleGraphStore at 0x14aaf2ba0>,
#  '_callback_manager': <llama_index.core.callbacks.base.CallbackManager at 0x13ec0ef10>,
#  '_object_map': {},
#  '_index_struct': IndexDict(index_id='e9c3c826-bc3a-409d-8167-5b465b2e2124', summary=None, nodes_dict={'fb1624a5-35ea-49d7-a575-ad6b79905f3d': 'fb1624a5-35ea-49d7-a575-ad6b79905f3d', '066e44b6-326a-484e-8542-0f902954d666': '066e44b6-326a-484e-8542-0f902954d666', '2ba11b80-6fcd-429f-9763-0a07ef989862': '2ba11b80-6fcd-429f-9763-0a07ef989862'}, doc_id_dict={}, embeddings_dict={}),
#  '_transformations': [SentenceSplitter(include_metadata=True, include_prev_next_rel=True, callback_manager=<llama_index.core.callbacks.base.CallbackManager object at 0x13ec0ef10>, id_func=<function default_id_func at 0x12ce7e520>, chunk_size=1024, chunk_overlap=200, separator=' ', paragraph_separator='\n\n\n', secondary_chunking_regex='[^,.;。？！]+[,.;。？！]?|[,.;。？！]')]}

# %% [markdown]
# * creating index from nodes

# %%
from llama_index.core import SimpleDirectoryReader


documents = SimpleDirectoryReader(input_files=["data/Eric-Jorgenson_The-Almanack-of-Naval-Ravikant_Final.pdf"]).load_data()

len(documents)
# Out:
# 242

# %%
from llama_index.core.node_parser import SentenceSplitter

splitter = SentenceSplitter(
    chunk_size=128,
    chunk_overlap=16,
    paragraph_separator="\n\n"
)

nodes = splitter.get_nodes_from_documents(
    documents=documents,
    show_progress=True
)
len(nodes)
# Out:
# Parsing nodes: 100%|██████████| 242/242 [00:00<00:00, 1940.69it/s]
# 967

# %%
index_2 = VectorStoreIndex(
    nodes=nodes,
    embed_model=embed_v3,
    show_progress=True
)
# Out:
# Generating embeddings: 100%|██████████| 967/967 [00:51<00:00, 18.93it/s]

# %% [markdown]
# ## Storing and Retrieving

# %%
from llama_index.embeddings.azure_openai import AzureOpenAIEmbedding

embed_model = AzureOpenAIEmbedding(
    model="text-embedding-3-small",
    deployment_name="text-embedding-3-small",
    azure_endpoint=AZURE_OPENAI_ENDPOINT,
    api_key=AZURE_API_KEY,
    api_version="2024-02-01", 
)

# %%
from llama_index.vector_stores.azureaisearch import AzureAISearchVectorStore
from llama_index.vector_stores.azureaisearch import IndexManagement
from azure.search.documents.indexes import SearchIndexClient
from azure.core.credentials import AzureKeyCredential

credential = AzureKeyCredential(AZURE_AI_SEARCH_API_KEY)
index_client = SearchIndexClient(endpoint=AZURE_AI_SEARCH_ENDPOINT, credential=credential)

index_name = "it_can_be_done"
vector_store = AzureAISearchVectorStore(
    search_or_index_client=index_client,
    index_name=index_name,
    index_management=IndexManagement.CREATE_IF_NOT_EXISTS,
    embed_model=embed_model,
    id_field_key="id",
    chunk_field_key="chunk",
    embedding_field_key="embedding",
    metadata_string_field_key="metadata",
    doc_id_field_key="doc_id",
)
# Out:
# async_search_or_index_client is None. Depending on the client type passed in, sync or async functions may not work.

# %%
from llama_index.core import StorageContext

storage_context = StorageContext.from_defaults(
    vector_store=vector_store,
    )

# %%
from llama_index.core import  VectorStoreIndex

# create the index
index = VectorStoreIndex.from_documents(
    documents,
    show_progress=True,
    store_nodes_override=True,
    transformation=[splitter],
    embed_model=embed_model,
    storage_context=storage_context,
)
# Out:
# Parsing nodes: 100%|██████████| 242/242 [00:00<00:00, 4436.96it/s]
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# Generating embeddings: 100%|██████████| 242/242 [00:11<00:00, 21.83it/s]

# %% [markdown]
# ### Retrieving

# %%
retriever = index.as_retriever(
    similarity_top_k=5,
    similarity_threshold=0.5)

# %%
retriever.retrieve("What is happiness?")
# Out:
# [NodeWithScore(node=TextNode(id_='4c52685c-4de9-4877-8275-5b89f0764fec', embedding=None, metadata={'page_label': '129', 'file_name': 'Eric-Jorgenson_The-Almanack-of-Naval-Ravikant_Final.pdf', 'file_path': 'data/Eric-Jorgenson_The-Almanack-of-Naval-Ravikant_Final.pdf', 'file_type': 'application/pdf', 'file_size': 1884309, 'creation_date': '2025-06-30', 'last_modified_date': '2025-06-30'}, excluded_embed_metadata_keys=['file_name', 'file_type', 'file_size', 'creation_date', 'last_modified_date', 'last_accessed_date'], excluded_llm_metadata_keys=['file_name', 'file_type', 'file_size', 'creation_date', 'last_modified_date', 'last_accessed_date'], relationships={<NodeRelationship.SOURCE: '1'>: RelatedNodeInfo(node_id='74f33b32-68f7-45ac-948c-af198485d230', node_type='4', metadata={'page_label': '129', 'file_name': 'Eric-Jorgenson_The-Almanack-of-Naval-Ravikant_Final.pdf', 'file_path': 'data/Eric-Jorgenson_The-Almanack-of-Naval-Ravikant_Final.pdf', 'file_type': 'application/pdf', 'file_size': 1884309, 'creation_date': '2025-06-30', 'last_modified_date': '2025-06-30'}, hash='a532af47692a36f67e34a975b04d02b9b21f383b85deeafd71d87c615bc4558d')}, metadata_template='{key}: {value}', metadata_separator='\n', text='LEARNING  HAPPINESS ·  129\nsatisfaction. For some people, it’ s a feeling of contentment. My \ndefinition keeps evolving. The answer I would have given you \na year ago will be different than what I tell you now.\nToday, I believe happiness is really a default state. Happiness \nis there when you remove the sense of something missing in \nyour life.\nWe are highly judgmental survival-and-replication machines. \nWe constantly walk around thinking, “I need this,” or “I need \nthat,” trapped in the web of desires. Happiness is the state \nwhen nothing is missing. When nothing is missing, your mind \nshuts down and stops running into the past or future to regret \nsomething or to plan something.\nIn that absence, for a moment, you have internal silence. When \nyou have internal silence, then you are content, and you are \nhappy. Feel free to disagree. Again, it’ s different for everybody.\nPeople mistakenly believe happiness is just about positive \nthoughts and positive actions. The more I’ve read, the more \nI’ve learned, and the more I’ve experienced (because I verify \nthis for myself ), every positive thought essentially holds within \nit a negative thought. It is a contrast to something negative. \nThe Tao Te Ching says this more articulately than I ever could, \nbut it’ s all duality and polarity. If I say I’m happy, that means I \nwas sad at some point. If I say he’ s attractive, then somebody \nelse is unattractive. Every positive thought even has a seed of \na negative thought within it and vice versa, which is why a lot \nof greatness in life comes out of suffering. You have to view the \nnegative before you can aspire to and appreciate the positive.\nTo me, happiness is not about positive thoughts. It’ s not about', mimetype='text/plain', start_char_idx=0, end_char_idx=1724, metadata_seperator='\n', text_template='{metadata_str}\n\n{content}'), score=0.6923096),
#  NodeWithScore(node=TextNode(id_='81fec382-798c-4176-bb66-dfc462cf1874', embedding=None, metadata={'page_label': '128', 'file_name': 'Eric-Jorgenson_The-Almanack-of-Naval-Ravikant_Final.pdf', 'file_path': 'data/Eric-Jorgenson_The-Almanack-of-Naval-Ravikant_Final.pdf', 'file_type': 'application/pdf', 'file_size': 1884309, 'creation_date': '2025-06-30', 'last_modified_date': '2025-06-30'}, excluded_embed_metadata_keys=['file_name', 'file_type', 'file_size', 'creation_date', 'last_modified_date', 'last_accessed_date'], excluded_llm_metadata_keys=['file_name', 'file_type', 'file_size', 'creation_date', 'last_modified_date', 'last_accessed_date'], relationships={<NodeRelationship.SOURCE: '1'>: RelatedNodeInfo(node_id='29d61ffe-4bc3-4ae2-92ab-c3e27270fc53', node_type='4', metadata={'page_label': '128', 'file_name': 'Eric-Jorgenson_The-Almanack-of-Naval-Ravikant_Final.pdf', 'file_path': 'data/Eric-Jorgenson_The-Almanack-of-Naval-Ravikant_Final.pdf', 'file_type': 'application/pdf', 'file_size': 1884309, 'creation_date': '2025-06-30', 'last_modified_date': '2025-06-30'}, hash='375a198322ac8496e8e9d4c1777c822727329d1a0194b7b47cf042ab2f796f4a')}, metadata_template='{key}: {value}', metadata_separator='\n', text='128  ·  THE ALMANACK OF NAVAL RAVIKANT\nHAPPINESS IS LEARNED\nTen years ago, if you would have asked me how happy I was, I \nwould have dismissed the question. I didn’t want to talk about \nit.\nOn a scale of 1–10, I would have said 2/10 or 3/10. Maybe 4/10 \non my best days. But I did not value being happy.\nToday, I am a 9/10. And yes, having money helps, but it’ s actu-\nally a very small piece of it. Most of it comes from learning over \nthe years my own happiness is the most important thing to me, \nand I’ve cultivated it with a lot of techniques.\xa0[10]\nMaybe happiness is not something you inherit or even \nchoose, but a highly personal skill that can be learned, like \nfitness or nutrition.\nHappiness is a very evolving thing, I think, like all the great \nquestions. When you’re a little kid, you go to your mom and \nask, “What happens when we die? Is there a Santa Claus? Is \nthere a God? Should I be happy? Who should I marry?” Those \nkinds of things. There are no glib answers because no answers \napply to everybody. These kinds of questions ultimately do \nhave answers, but they have personal answers.\nThe answer that works for me is going to be nonsense to you, \nand vice versa. Whatever happiness means to me, it means \nsomething different to you. I think it’ s very important to \nexplore what these definitions are.\nFor some people I know, it’ s a flow state. For some people, it’ s', mimetype='text/plain', start_char_idx=0, end_char_idx=1391, metadata_seperator='\n', text_template='{metadata_str}\n\n{content}'), score=0.6767578),
#  NodeWithScore(node=TextNode(id_='d5b3ef65-2cde-49f4-aa98-45be923b1656', embedding=None, metadata={'page_label': '145', 'file_name': 'Eric-Jorgenson_The-Almanack-of-Naval-Ravikant_Final.pdf', 'file_path': 'data/Eric-Jorgenson_The-Almanack-of-Naval-Ravikant_Final.pdf', 'file_type': 'application/pdf', 'file_size': 1884309, 'creation_date': '2025-06-30', 'last_modified_date': '2025-06-30'}, excluded_embed_metadata_keys=['file_name', 'file_type', 'file_size', 'creation_date', 'last_modified_date', 'last_accessed_date'], excluded_llm_metadata_keys=['file_name', 'file_type', 'file_size', 'creation_date', 'last_modified_date', 'last_accessed_date'], relationships={<NodeRelationship.SOURCE: '1'>: RelatedNodeInfo(node_id='c5f7869e-1f48-46b7-a10b-4700d12c06f8', node_type='4', metadata={'page_label': '145', 'file_name': 'Eric-Jorgenson_The-Almanack-of-Naval-Ravikant_Final.pdf', 'file_path': 'data/Eric-Jorgenson_The-Almanack-of-Naval-Ravikant_Final.pdf', 'file_type': 'application/pdf', 'file_size': 1884309, 'creation_date': '2025-06-30', 'last_modified_date': '2025-06-30'}, hash='e48f91797c026045e441c915d8679c244cde7d78312f8be2b1cc74248b7bfde9')}, metadata_template='{key}: {value}', metadata_separator='\n', text='LEARNING  HAPPINESS ·  145\nOnce I came to that realization, jealousy faded away because \nI don’t want to be anybody else. I’m perfectly happy being me. \nBy the way, even that is under my control. To be happy being \nme. It’ s just there are no social rewards for it.\xa0[4]\nHAPPINESS IS BUILT BY HABITS\nMy most surprising discovery in the last five years is that peace \nand happiness are skills. These are not things you are born \nwith. Yes, there is a genetic range. And a lot of it is conditioning \nfrom your environment, but you can un-condition and recon-\ndition yourself.\nYou can increase your happiness over time, and it starts with \nbelieving you can do it.\nIt’ s a skill. Just like nutrition is a skill, dieting is a skill, working \nout is a skill, making money is a skill, meeting girls and guys is \na skill, having good relationships is a skill, even love is a skill. \nIt starts with realizing they’re skills you can learn. When you \nput your intention and focus on it, the world can become a \nbetter place.\nWhen working, surround yourself with people more \nsuccessful than you.\nWhen playing, surround yourself with people happier than \nyou.\nWhat type of skill is happiness?', mimetype='text/plain', start_char_idx=0, end_char_idx=1180, metadata_seperator='\n', text_template='{metadata_str}\n\n{content}'), score=0.6633761)]
